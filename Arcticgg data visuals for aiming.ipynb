# %%
import pandas as pd
# %matplotlib inline

# %%
from matplotlib import pyplot as plt

# %%
arctic_data = pd.read_csv('arcticgg_data.csv')

# %%
arctic_data
# Out:
#                       name      level          mode  is_benchmark  mouse_sens  \
# 0     Wrist Aiming Level 1          1         wrist             0      1.5000
# 1     Wrist Aiming Level 1          1         wrist             0      0.6909
# 2     Wrist Aiming Level 1          1         wrist             0      0.6909
# 3     Wrist Aiming Level 1          1         wrist             0      0.6909
# 4     Wrist Aiming Level 2          2         wrist             0      0.5360
# ...                    ...        ...           ...           ...         ...
# 999                  Flick  Benchmark  benchmarkNew             1      0.6909
# 1000                 Flick  Benchmark  benchmarkNew             1      0.6909
# 1001                 Flick  Benchmark  benchmarkNew             1      0.6909
# 1002         Target Frenzy  Benchmark  benchmarkNew             1      0.6909
# 1003         Target Frenzy  Benchmark  benchmarkNew             1      0.6909
#
# ...

# %%
type(arctic_data)
# Out:
# pandas.core.frame.DataFrame

# %%
arctic_data.name
# Out:
# 0       Wrist Aiming Level 1
# 1       Wrist Aiming Level 1
# 2       Wrist Aiming Level 1
# 3       Wrist Aiming Level 1
# 4       Wrist Aiming Level 2
#                 ...
# 999                    Flick
# 1000                   Flick
# 1001                   Flick
# 1002           Target Frenzy
# 1003           Target Frenzy
# Name: name, Length: 1004, dtype: object

# %%
arctic_data.name.iloc[0]
# Out:
# 'Wrist Aiming Level 1'

# %%
plt.plot(arctic_data.accuracy, arctic_data.av_full_path_time, 'o')
plt.plot (arctic_data.accuracy, arctic_data.mouse_pixel_speed, 'o')
plt.show()

# %%
#isolate flick aiming game

# %%
flicks = arctic_data[arctic_data.name == 'Flick']

# %%
flicks
# Out:
#        name      level          mode  is_benchmark  mouse_sens  fov fov_type  \
# 185   Flick  Benchmark  benchmarkNew             1      1.5000   79        h
# 187   Flick  Benchmark  benchmarkNew             1      1.5000   79        h
# 188   Flick  Benchmark  benchmarkNew             1      1.5000   79        h
# 189   Flick  Benchmark  benchmarkNew             1      0.5360   90        h
# 190   Flick  Benchmark  benchmarkNew             1      0.5360   90        h
# ...     ...        ...           ...           ...         ...  ...      ...
# 997   Flick  Benchmark  benchmarkNew             1      0.6909   90        h
# 998   Flick  Benchmark  benchmarkNew             1      0.6909   90        h
# 999   Flick  Benchmark  benchmarkNew             1      0.6909   90        h
# 1000  Flick  Benchmark  benchmarkNew             1      0.6909   90        h
# 1001  Flick  Benchmark  benchmarkNew             1      0.6909   90        h
#
# ...

# %%
plt.plot(flicks.accuracy, flicks.av_full_path_time, 'o')
plt.plot (flicks.accuracy, flicks.mouse_pixel_speed, 'o')
plt.show()

# %%
arctic_data.columns
# Out:
# Index(['name', 'level', 'mode', 'is_benchmark', 'mouse_sens', 'fov',
#        'fov_type', 'accuracy', 'time_destroy', 'crit_hit', 'targets_destroyed',
#        'mouse_travel_efficiency', 'mouse_pixel_speed', 'av_reaction_time',
#        'av_full_path_time', 'prct_late_shots', 'av_late_shot_time',
#        'paths_analysed', 'initial_move_angle', 'game_area', 'game_program'],
#       dtype='object')

# %%
arctic_data.shape
# Out:
# (1004, 21)

# %%
arctic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1004 entries, 0 to 1003
# Data columns (total 21 columns):
# name                       1004 non-null object
# level                      882 non-null object
# mode                       1004 non-null object
# is_benchmark               1004 non-null int64
# mouse_sens                 1004 non-null float64
# fov                        1004 non-null int64
# fov_type                   1004 non-null object
# accuracy                   1004 non-null float64
# time_destroy               1004 non-null int64
# crit_hit                   1004 non-null float64
# targets_destroyed          1004 non-null int64
# mouse_travel_efficiency    906 non-null float64
# mouse_pixel_speed          906 non-null float64
# av_reaction_time           906 non-null float64
# av_full_path_time          906 non-null float64
# prct_late_shots            906 non-null float64
# av_late_shot_time          194 non-null float64
# ...

# %%
sens = arctic_data[arctic_data.mouse_sens == '0.6909']
# Out:
# G:\ana\lib\site-packages\pandas\core\ops\__init__.py:1115: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
pd.scatter_matrix(arctic_data.loc[:,"accuracy" : 'targets_destroyed'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-67a74793b83f> in <module>
# ----> 1 pd.scatter_matrix(arctic_data.loc[:,"accuracy" : 'targets_destroyed'])
#       2 plt.show()
#
# G:\ana\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     212
#     213             return Panel
# --> 214         raise AttributeError("module 'pandas' has no attribute '{}'".format(name))
#     215
#     216
#
# AttributeError: module 'pandas' has no attribute 'scatter_matrix'

# %%
from pandas.plotting import scatter_matrix

# %%
pd.plotting.scatter_matrix(arctic_data.loc[:,'targets_destroyed' : 'av_full_path_time'],figsize = (18,16))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000175DB40BAC8>,
# ...
#       dtype=object)
